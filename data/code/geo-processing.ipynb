# %% [markdown]
# This script creates geojson filles.
#
# Data was originally downloaded from the
# Humanitarian Data Exchange / UN Office for
# the Coordination of Humanitarian Affairs.
#
# They were processed to be in the format
# needed for the application to run.
#
# The file dids not originally include the
# 'Zona en Reclamación'.
#
# https://data.humdata.org/dataset/cod-ab-ven0

# %%
import geopandas as gpd
import pandas as pd

# %% [markdown]
# #### Geographic file processing

# %% [markdown]
# Converts province data to GeoJSON.

# %%
provincias = gpd.read_file("../input/provincias.zip")
provincias = provincias[['ADM1_ES', 'ADM1_PCODE', 'geometry']]
provincias = provincias.rename(columns={'ADM1_ES': 'name', 'ADM1_PCODE': 'code'})
provincias.loc[24, 'code'] = 'VE99' # Code for Federal Dependencies was nan

provincias.to_file("../output/level-1.geojson", driver="GeoJSON")

# %% [markdown]
# The second level of the data visualization will include the 'municipios' division for all the states plus the 'paroquias' for Vargas and Distrito Capital. We will combine them into a single file

# %%
municipios = gpd.read_file("../input/municipios.zip")

# %%
paroquias = gpd.read_file("../input/paroquias.zip")

# %%
# All municipios but Libertador (Distrito Capital) and Vargas (La Guaira)
municipios = municipios[~municipios.ADM1_PCODE.isin(['VE01', 'VE24'])]
municipios = municipios[['ADM1_PCODE', 'ADM1_ES', 'ADM2_PCODE', 'ADM2_ES', 'geometry']]
municipios = municipios.rename(columns={
                                        'ADM1_ES': 'parent_name', 
                                        'ADM1_PCODE': 'parent_code',
                                        'ADM2_ES': 'name', 
                                        'ADM2_PCODE': 'code'})

# %%
paroquias = paroquias[paroquias.ADM1_PCODE.isin(['VE01', 'VE24'])] # Paroquias in Libertador and Vargas
paroquias = paroquias[['ADM1_PCODE', 'ADM1_ES', 'ADM3_PCODE', 'ADM3_ES', 'geometry']]
paroquias = paroquias.rename(columns={
                                      'ADM1_ES': 'parent_name', 
                                      'ADM1_PCODE': 'parent_code',
                                      'ADM3_ES': 'name', 
                                      'ADM3_PCODE': 'code'
})

# %%
level_2 = pd.concat([municipios, paroquias]).sort_values(by='parent_name')

# %%
level_2.to_file("../output/level-2.geojson", driver="GeoJSON")

# %%
# Renames
# Out:
#     level_1_name                       level_2_name  level_1_code  \
# 0       Amazonas        Alto Orinoco (La Esmeralda)           NaN
# 1       Amazonas  Atabapo (San Fernando de Atabapo)           NaN
# 2       Amazonas           Atures (Puerto Ayacucho)           NaN
# 3       Amazonas                Autana (Isla Ratón)           NaN
# 4       Amazonas  Manapiare (San Juan de Manapiare)           NaN
# ..           ...                                ...           ...
# 361        Zulia                      San Francisco           NaN
# 362        Zulia                         Santa Rita           NaN
# 363        Zulia          Semprún (Casigua El Cubo)           NaN
# 364        Zulia                    Sucre (Bobures)           NaN
# 365        Zulia     Valmore Rodríguez (Bachaquero)           NaN
#
#      level_2_code
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 361           NaN
# 362           NaN
# 363           NaN
# 364           NaN
# 365           NaN
#
# [366 rows x 4 columns]

# %%
# Out:
#          level_1_name                level_2_name  level_1_code  level_2_code  \
# 103  Distrito capital       Parroquia 23 de enero           NaN           NaN
# 104  Distrito capital        Parroquia Altagracia           NaN           NaN
# 105  Distrito capital          Parroquia Antímano           NaN           NaN
# 106  Distrito capital        Parroquia Candelaria           NaN           NaN
# 107  Distrito capital          Parroquia Caricuao           NaN           NaN
# 108  Distrito capital          Parroquia Catedral           NaN           NaN
# 109  Distrito capital             Parroquia Coche           NaN           NaN
# 110  Distrito capital       Parroquia El Junquito           NaN           NaN
# 111  Distrito capital        Parroquia El Paraíso           NaN           NaN
# 112  Distrito capital         Parroquia El Recreo           NaN           NaN
# 113  Distrito capital          Parroquia El Valle           NaN           NaN
# 114  Distrito capital        Parroquia La Pastora           NaN           NaN
# 115  Distrito capital           Parroquia La Vega           NaN           NaN
# 116  Distrito capital           Parroquia Macarao           NaN           NaN
# 117  Distrito capital       Parroquia San Agustín           NaN           NaN
# 118  Distrito capital    Parroquia San Bernardino           NaN           NaN
# 119  Distrito capital          Parroquia San José           NaN           NaN
# 120  Distrito capital          Parroquia San Juan           NaN           NaN
# 121  Distrito capital         Parroquia San Pedro           NaN           NaN
# 122  Distrito capital     Parroquia Santa Rosalía           NaN           NaN
# 123  Distrito capital      Parroquia Santa Teresa           NaN           NaN
# 124  Distrito capital             Parroquia Sucre           NaN           NaN
# 320            Vargas       Parroquia Caraballeda           NaN           NaN
# 321            Vargas          Parroquia Carayaca           NaN           NaN
# 322            Vargas  Parroquia Carlos Soublette           NaN           NaN
# 323            Vargas            Parroquia Caruao           NaN           NaN
# 324            Vargas      Parroquia Catia La Mar           NaN           NaN
# 325            Vargas          Parroquia El Junko           NaN           NaN
# 326            Vargas         Parroquia La Guaira           NaN           NaN
# 327            Vargas            Parroquia Macuto           NaN           NaN
# 328            Vargas         Parroquia Maiquetía           NaN           NaN
# 329            Vargas          Parroquia Naiguatá           NaN           NaN
# 330            Vargas           Parroquia Urimare           NaN           NaN
#
#                           matches
# 103                   23 de Enero
# 104                    Altagracia
# 105
# 106        Candelaria, Candelaria
# 107                      Caricuao
# 108                      Catedral
# 109                         Coche
# 110                   El Junquito
# 111                    El Paraíso
# 112                     El Recreo
# 113                      El Valle
# 114                    La Pastora
# 115                       La Vega
# 116                       Macarao
# 117                   San Agustín
# 118
# 119                      San José
# 120                      San Juan
# 121                     San Pedro
# 122  Santa Rosalía, Santa Rosalía
# 123                  Santa Teresa
# 124                  Sucre, Sucre
# 320                   Caraballeda
# 321                      Carayaca
# 322              Carlos Soublette
# 323                        Caruao
# 324                  Catia la Mar
# 325                      El Junko
# 326                     La Guaira
# 327                        Macuto
# 328                     Maiquetía
# 329
# 330                       Urimare
