# %%
'''
A test for a bubble map instead of a choropleth
'''
# Out:
# '\nA test for a bubble map instead of a choropleth\n'

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file("../output/finished-geojsons/level_2_results.geojson")

# %%
gdf.plot()
# Out:
# <Axes: >
